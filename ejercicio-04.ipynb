# %% [markdown]
# Con este archivo, construir un objeto de series de tiempo con el índice igual al año de los juegos olímpicos

# %%
import pandas as pd

# %%
df = pd.read_csv('Summer-Olympic-medals-1976-to-2008.csv', encoding= 'iso8859-1', sep=',')

# %%
df
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               KÖHLER, Christa  Women          GDR   East Germany
# ...

# %%
df0=df.isna().sum()
df0
# Out:
# City            117
# Year            117
# Sport           117
# Discipline      117
# Event           117
# Athlete         117
# Gender          117
# Country_Code    117
# Country         117
# Event_gender    117
# Medal           117
# dtype: int64

# %%
df1=df[['Year', 'Country', 'City','Sport', 'Discipline', 'Event', 'Athlete', 'Gender',
       'Country_Code','Event_gender', 'Medal']]
df1
# Out:
#          Year        Country      City      Sport       Discipline  \
# 0      1976.0   East Germany  Montreal   Aquatics           Diving
# 1      1976.0   Soviet Union  Montreal   Aquatics           Diving
# 2      1976.0  United States  Montreal   Aquatics           Diving
# 3      1976.0          Italy  Montreal   Aquatics           Diving
# 4      1976.0  United States  Montreal   Aquatics           Diving
# ...       ...            ...       ...        ...              ...
# 15428  2008.0         France   Beijing  Wrestling  Wrestling Gre-R
# 15429  2008.0        Georgia   Beijing  Wrestling  Wrestling Gre-R
# 15430  2008.0     Azerbaijan   Beijing  Wrestling  Wrestling Gre-R
# 15431  2008.0         France   Beijing  Wrestling  Wrestling Gre-R
# 15432  2008.0           Cuba   Beijing  Wrestling  Wrestling Gre-R
#
#                 Event                   Athlete Gender Country_Code  \
# 0      3m springboard           KÖHLER, Christa  Women          GDR
# ...

# %% [markdown]
# Separar nombres de apellidos en dos columnas distintas usando la coma como separador

# %%
df2 = df["Athlete"].str.split(',', expand=True) 
df2
# Out:
#                0                1     2
# 0         KÖHLER          Christa  None
# 1       KOSENKOV        Aleksandr  None
# 2          BOGGS    Philip George  None
# 3       CAGNOTTO   Giorgio Franco  None
# 4         WILSON   Deborah Keplar  None
# ...          ...              ...   ...
# 15428     GUENOT       Christophe  None
# 15429  KVIRKELIA         Manuchar  None
# 15430    RAHIMOV          Vitaliy  None
# 15431     GUENOT           Steeve  None
# 15432      LOPEZ           Mijain  None
#
# [15433 rows x 3 columns]

# %% [markdown]
# Obtener medidas resumen del conjunto de datos. Cuál es el país que ganó más medallas?

# %%
df.groupby(['Country']).size().reset_index(name='Cantidad de Medallas')
# Out:
#              Country  Cantidad de Medallas
# 0        Afghanistan                     1
# 1            Algeria                    14
# 2          Argentina                   153
# 3            Armenia                     9
# 4          Australia                   798
# ..               ...                   ...
# 122  Virgin Islands*                     1
# 123     West Germany                   345
# 124       Yugoslavia                   278
# 125           Zambia                     2
# 126         Zimbabwe                    23
#
# [127 rows x 2 columns]

# %%
df["Country"].value_counts()
# Out:
# United States      1992
# Soviet Union       1021
# Australia           798
# Germany             691
# China               679
#                    ...
# Cote d'Ivoire         1
# Djibouti              1
# Senegal               1
# Virgin Islands*       1
# Afghanistan           1
# Name: Country, Length: 127, dtype: int64

# %% [markdown]
# El País que más gano medallas fue EEUU

# %%
df.groupby(['Year','Gender']).size().reset_index(name='medallas')
# Out:
#       Year Gender  medallas
# 0   1976.0    Men       924
# 1   1976.0  Women       381
# 2   1980.0    Men       958
# 3   1980.0  Women       429
# 4   1984.0    Men       973
# 5   1984.0  Women       486
# 6   1988.0    Men      1011
# 7   1988.0  Women       535
# 8   1992.0    Men      1105
# 9   1992.0  Women       600
# 10  1996.0    Men      1082
# 11  1996.0  Women       777
# 12  2000.0    Men      1126
# 13  2000.0  Women       889
# 14  2004.0    Men      1099
# 15  2004.0  Women       899
# 16  2008.0    Men      1110
# 17  2008.0  Women       932

# %% [markdown]
# Cantidad de Medallas por genero
